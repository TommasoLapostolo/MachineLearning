# %% [markdown]
# # Esercizio Introduttivo
#
# In questo esercizio introduttivo dovrai sviluppare un semplice metodo di regressione lineare con scipy. Puoi trovare tutte le informazioni su come fare la regression con scipy all'url: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html

# %% [markdown]
# ### Assignment
#
# 1) Carica il file .csv fornito con i dati delle auto usate
#
# 2) Utilizza una regressione lineare per stimare i prezzi delle auto in base all'anno, ai chilometri percorsi o alla potenza del motore. Puoi effettuare una semplice regressione 1D da ciascuno dei parametri in modo indipendente (facoltativo: puoi anche provare una regressione 2D o 3D combinando più parametri)
#
# 3) Per prima cosa esegui la stima utilizzando la funzione linregress di scipy (o in alternativa puoi utilizzare la classe sklearn.linear_model.LinearRegression). NB: controlla la documentazione dei due metodi!! In particolare, fai attenzione al numero di output (in caso usa "_" per evitare un output specifico nel return della funzione).
#
# 4) Dai un'occhiata al coefficiente di correlazione per vedere quale delle 3 caratteristiche funziona meglio
#
# 5) (facoltativo) Implementa a mano l'algoritmo dei minimi quadrati: dovresti ottenere esattamente la stessa soluzione di linregress!
#
# 6) Traccia i dati e le rette che rappresentano l'output degli algoritmi linregress e minimi quadrati

# %%
import matplotlib.pyplot as plt
import csv
from scipy import stats
import numpy as np
import sklearn as sl
from sklearn import linear_model as lm
#aggiunte da me
#from scipy.stats import linregress

# %%
# Carica i file dati con le informazioni sulle auto usate (prova ad aprirlo con un text editor per vedere il contenuto!)

filename = "data/km_year_power_price.csv"
lines = csv.reader(open(filename, newline=''), delimiter=',')

# carico i dati
dataset = list(lines)
#print(dataset)
#print(len(dataset))
arrayset = np.array(dataset)
#print(len(ar))
print(type(arrayset)) #ovviamnete mi stampa numpy.ndarray!!!!
print(type(arrayset[1,1])) #voglio vedere che tipo di dati contiene l'array, a mia sorpresa sono stringhe e non float
print() #spazio
print(arrayset)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.str_'>
#
# [['km' 'year' 'powerPS' 'avgPrice']
#  ['125000' '2001' '40' '1371.11']
#  ['150000' '2001' '40' '1298.70']
#  ...
#  ['20000' '2015' '260' '49492.38']
#  ['10000' '2015' '300' '38542.69']
#  ['20000' '2015' '300' '39683.32']]

# %% [markdown]
# Usa la regressione lineare per stimare i prezzi delle auto in base all'anno, ai chilometri o alla potenza del motore. È possibile effettuare una semplice regressione 1D da ciascuno dei parametri in modo indipendente

# %%
# Regressione lineare con linregress (stima il prezzo dall'anno)
# l'arrayset è del tipo [n,4]
# ora creo 4 array [1,n] per linregress, mi ricordo di saltare la prima riga che è di tipo string
km = np.array(arrayset[1:,0], dtype=float) #dtype=float converte il dato dell'array che è di tipo string
year = np.array(arrayset[1:,1], dtype=float)
pw = np.array(arrayset[1:,2], dtype=float)
price = np.array(arrayset[1:,-1], dtype=float)
#print(km)
#print(year)
#print(pw)
#print(price)
lryear = stats.linregress(year, price)

# %%
# (Opzionale) regressione lineare con linear_model.LinearRegression() (stima il prezzo dall'anno)
# Ricorda che in Python una  matrice mx1 è diversa da un array 1D -> usa reshape
# creo la variabile adattandola alla funzione
year1 = np.array(arrayset[1:,1], dtype=float).reshape(-1, 1) #-1 fa sì che NumPy calcoli automaticamente il numero di righe. 1 indica che vogliamo una sola colonna.
# faccio la regressione lineare con sklearn
model = lm.LinearRegression() #creo la variabile
model.fit(year1, price)  # Addestra il modello
ccy = np.sqrt(model.score(year1,price)) # coefficiente di correlazione
#plotto i dati year-price
plt.plot(year1, price, 'o', label='year-price') #plotta i punti/dati
plt.plot(year1, model.predict(year1), 'r', label='fitted line') #plotta il fit della regressione lineare
plt.legend()
plt.show()

#faccio lo stesso per la stima del prezzo dai km
# creo la variabile addattandola alla funzione
km1 = np.array(arrayset[1:,0], dtype=float).reshape(-1, 1);
#regressione lineare
model.fit(km1, price)
cck = -np.sqrt(model.score(km1,price))
#plotto i dati km-price
plt.plot(km1, price, 'o', label='km-price') #plotta i punti/dati
plt.plot(km1, model.predict(km1), 'r', label='fitted line') #plotta il fit della regressione lineare
plt.legend()
plt.show()

#faccio lo stesso per la stima del prezzo dal power
# creo la variabile addattandola alla funzione
pw1 = np.array(arrayset[1:,2], dtype=float).reshape(-1, 1)
model.fit(pw1, price)
ccp = np.sqrt(model.score(pw1,price))
#plotto i dati pw-price
plt.plot(pw1, price, 'o', label='km-price') #plotta i punti/dati
plt.plot(pw1, model.predict(pw1), 'r', label='fitted line') #plotta il fit della regressione lineare
plt.legend()
plt.show()

#coefficiente di correlazione
print("Coefficiente di correlazione year-price:", ccy)
print("Coefficiente di correlazione km-price:", cck)
print("Coefficiente di correlazione power-price:", ccp)
# Out:
# Coefficiente di correlazione year-price: 0.6767043169095441
# Coefficiente di correlazione km-price: -0.25728674299884985
# Coefficiente di correlazione power-price: 0.7085500315263967

# %%
# (Opzionale) implementa la regressione lineare coi minimi quadrati "a mano" senza usare le funzioni di Python
# Dovresti ottenere lo stesso risultato di linregress !

# your code.....

# %%
# Regressione lineare con linregress (stima il prezzo dalla potenza)
lrpw = stats.linregress(pw, price)

# %%
# regressione lineare con linregress (stima il prezzo dai chilometri)
lrkm = stats.linregress(km, price)

# %%
# Plotta i dati e le linee che rappresentano l'output degli algoritmi linregress e dei minimi quadrati
# slope : float : pendenza della retta di regressione
# intercept : float : intercetta della retta di regressione

# plot year-price
plt.plot(year, price, 'o', label='year-price') #plotta i punti/dati
plt.plot(year, lryear.intercept + lryear.slope*year, 'r', label='fitted line') #plotta il fit della regressione lineare
plt.legend()
plt.show()

# plot power-price
plt.plot(pw, price, 'o', label='power-price')
plt.plot(pw, lrpw.intercept + lrpw.slope*pw, 'r', label='fitted line')
plt.legend()
plt.show()

# plot km-price
plt.plot(km, price, 'o', label='km-price')
plt.plot(km, lrkm.intercept + lrkm.slope*km, 'r', label='fitted line')
plt.legend()
plt.show()

# %%
# Dai un'occhiata ai coefficienti di correlazione per vedere quale delle 3 caratteristiche funziona meglio
# rvalue : float : coefficient di correlazione (vedi box, ±1 : corr. totale, 0 no correlazione)
print("Coefficiente di correlazione year-price:", lryear.rvalue)
print("Coefficiente di correlazione power-price:", lrpw.rvalue)
print("Coefficiente di correlazione km-price:", lrkm.rvalue)

print()

#funzione che determina il miglior coefficiente di correlazione
#confronto massimo tra 3 coefficienti, se ne ho 2 metto che uno vale 0
def ccc(a, b, c):
    x = a
    if ((1 - abs(x)) > (1 - abs(b))):
        x = b
    if ((1 - abs(x)) > (1 - abs(c))):
        x = c
    return x

print("Il miglio coefficiente di correlazione è:", ccc(lryear.rvalue, lrpw.rvalue, lrkm.rvalue))
# Out:
# Coefficiente di correlazione year-price: 0.6767043169095447
# Coefficiente di correlazione power-price: 0.708550031526397
# Coefficiente di correlazione km-price: -0.2572867429988497
#
# Il miglio coefficiente di correlazione è: 0.708550031526397

# %%
#FATTO DA GPT
# Combina km e year in un unico array 2D (km, year)
kmyear = np.column_stack((km, year))  # Unisce km e year in un array 2D

# Fai la regressione lineare
model = lm.LinearRegression()
model.fit(kmyear, price)

# Calcola il coefficiente di determinazione R^2
r2_score = model.score(kmyear, price)

# Calcola il coefficiente di correlazione r (radice quadrata di R^2)
r_value = np.sqrt(r2_score)
print(f"Coefficiente di correlazione (r) per year e km -> price: {r_value:.4f}")

# Plot dei dati (km-price) e della retta di regressione
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')  # 3D plotting

# Plot dei dati originali
ax.scatter(km, year, price, color='blue', label='Original data')

# Creare una griglia per la previsione (km, year)
km_range = np.linspace(min(km), max(km), 100)  # km values
year_range = np.linspace(min(year), max(year), 100)  # year values
km_grid, year_grid = np.meshgrid(km_range, year_range)  # Crea la griglia 2D
kmyear_grid = np.column_stack((km_grid.ravel(), year_grid.ravel()))  # Combina in un array 2D

# Previsione dei valori per la griglia di km e year
price_pred_grid = model.predict(kmyear_grid)

# Ridimensiona le previsioni per il piano
price_pred_grid = price_pred_grid.reshape(km_grid.shape)

# Plot della superficie di regressione in 3D
ax.plot_surface(km_grid, year_grid, price_pred_grid, color='red', alpha=0.5, label='Fitted plane')

# Etichette degli assi
ax.set_xlabel('Kilometraggio')
ax.set_ylabel('Anno')
ax.set_zlabel('Prezzo')

# Posizione fissa della legenda
ax.legend(loc='upper left')  # Usa una posizione fissa per la legenda

# Migliora il layout del grafico
plt.tight_layout()

# Mostra il grafico
plt.show()

# Visualizza il coefficiente di determinazione R^2
print(f"Coefficiente di determinazione (R^2): {r2_score:.4f}")
# Out:
# Coefficiente di correlazione (r) per year e km -> price: 0.6767
# Coefficiente di determinazione (R^2): 0.4580

# %%
#NON GIUSTO
# (Opzionale) regressione lineare 2D con linear model (ad es. stima il prezzo da anno e km)
# creo la variabile adattandola alla funzione
#Combina km e year in un unico array 2D (km, year)
kmyear = np.column_stack((km, year))  # Unisce km e year in un array 2D
# faccio la regressione lineare con sklearn
model = lm.LinearRegression() #creo la variabile
model.fit(kmyear, price)  # Addestra il modello
ccy = np.sqrt(model.score(kmyear,price)) # coefficiente di correlazione
#plotto i dati year-price
plt.plot(kmyear, price, 'o', label='kmyear-price') #plotta i punti/dati
plt.plot(kmyear, model.predict(kmyear), 'r', label='fitted line') #plotta il fit della regressione lineare
plt.legend()
plt.show()

#coefficiente di correlazione
print("Coefficiente di correlazione year-price:", ccy)
# Out:
# Coefficiente di correlazione year-price: 0.6767212925160223

# %%
# (Opzionale) regressione lineare 3D con linear model (ad es. stima il prezzo da anno e potenza)
# your code......
